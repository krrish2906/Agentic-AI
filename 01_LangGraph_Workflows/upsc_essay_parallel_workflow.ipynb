# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
import os

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(
    model="gpt-4o-mini",
    openai_api_key=os.getenv("OPENROUTER_API_KEY"),
    openai_api_base="https://openrouter.ai/api/v1"
)

# %%
class EvaluationSchema(BaseModel):
    feedback: str = Field(description="Detailed feedback for the essay")
    score: int = Field(description="Score from 1-10", ge=1, le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10:\n{essay}'
result = structured_model.invoke(prompt)
print("Score:", result.score)
print("Feedback:", result.feedback)
# Out:
# Score: 8
# Feedback: The essay presents a well-structured discussion on the relevance of AI in India, highlighting the country's strengths, opportunities, and challenges associated with artificial intelligence. The language is articulate, with a professional tone that effectively communicates the complexities and nuances of the topic. The use of specific examples, such as the applications of AI in agriculture and healthcare, adds depth and relevance to the argument, making it engaging for the reader. Moreover, the transition between paragraphs is smooth, maintaining a logical flow throughout the piece.
#
# That said, there are a few areas that could be improved. Firstly, the essay could benefit from a more engaging introduction; while it sets the context, a captivating hook could draw the reader in more effectively. Additionally, there are minor instances of repetition, particularly when discussing challenges like the digital divide and ethical concerns, which could be streamlined for clarity. Lastly, while the essay touches on international collaboration, it could elaborate further on specific partnerships or models that India could consider, enhancing the practical applicability of the suggestions made.
#
# Overall, the essay demonstrates a strong command of language and ideas, with just a few minor adjustments needed for improvement.

# %%
import operator
class UPSCEssayEvaluator(TypedDict):
    essay: str
    language_feedback: str
    clarity_feedback: str
    analysis_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    average_score: float

# %%
def language_evaluator(state: UPSCEssayEvaluator):
    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10:\\n{state["essay"]}'
    response = structured_model.invoke(prompt)
    return {
        "language_feedback": response.feedback,
        "individual_scores": [response.score]
    }

# %%
def clarity_evaluator(state: UPSCEssayEvaluator):
    prompt = f'Evaluate the clarity and coherence of the following essay and provide a feedback and assign a score out of 10:\\n{state["essay"]}'
    response = structured_model.invoke(prompt)
    return {
        "clarity_feedback": response.feedback,
        "individual_scores": [response.score]
    }

# %%
def analysis_evaluator(state: UPSCEssayEvaluator):
    prompt = f'Evaluate the analysis and critical thinking of the following essay and provide a feedback and assign a score out of 10:\\n{state["essay"]}'
    response = structured_model.invoke(prompt)
    return {
        "analysis_feedback": response.feedback,
        "individual_scores": [response.score]
    }

# %%
def overall_evaluator(state: UPSCEssayEvaluator):
    prompt = f'Based on the following feedbacks create a summarized feedback \nlanguage feedback - {state["language_feedback"]} \ndepth of analysis feedback - {state["analysis_feedback"]} \nclarity of thought feedback - {state["clarity_feedback"]}'

    overall_feedback = model.invoke(prompt).content
    avg_score = sum(state['individual_scores']) / len(state['individual_scores'])
    return {'overall_feedback': overall_feedback, 'avg_score': avg_score}

# %%
graph = StateGraph(UPSCEssayEvaluator)

graph.add_node("language_evaluator", language_evaluator)
graph.add_node("clarity_evaluator", clarity_evaluator)
graph.add_node("analysis_evaluator", analysis_evaluator)
graph.add_node("overall_evaluator", overall_evaluator)

graph.add_edge(START, "language_evaluator")
graph.add_edge(START, "clarity_evaluator")
graph.add_edge(START, "analysis_evaluator")
graph.add_edge("language_evaluator", "overall_evaluator")
graph.add_edge("clarity_evaluator", "overall_evaluator")
graph.add_edge("analysis_evaluator", "overall_evaluator")
graph.add_edge("overall_evaluator", END)

workflow = graph.compile()

# %%
from IPython.display import Image
Image(workflow.get_graph().draw_mermaid_png())

# %%
initial_state = {"essay": essay}
final_state = workflow.invoke(initial_state)
final_state
# Out:
# {'essay': "India in the Age of AI\nAs the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.\n\nIndia's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.\n\nOne of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.\n\nHowever, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.\n\nAnother pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.\n\nTo harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.\n\nIndia’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.\n\nIn conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.",
#  'language_feedback': "The language quality of the essay is commendable, characterized by clear organization and a logical flow of ideas. The introduction succinctly sets the stage for the discussion on AI in India, while body paragraphs effectively elaborate on both the potential and challenges posed by AI. The use of varied sentence structures and a strong vocabulary enhances the overall readability of the text. However, there are occasional instances where sentences could be more concise, and some ideas could benefit from further elaboration for clarity. Additionally, the essay could be strengthened by integrating more specific examples or data points to support claims made, particularly in discussing the challenges of digital divide and job displacement. Overall, the essay effectively communicates India's position in the AI landscape while also addressing the critical areas needing attention for responsible AI adoption.",
#  'clarity_feedback': "The essay provides a comprehensive overview of India's position in the AI landscape, capturing both its potential and challenges. The structure is logical, transitioning smoothly from India's strengths to applications of AI, followed by the challenges and necessary strategies. However, some sentences could be more concise to enhance clarity, such as the discussion around technical institutions and private sector contributions. Additionally, while many important points are mentioned, delving deeper into specific examples or case studies could further bolster coherence, illustrating how these strategies have been or could be developed effectively. Overall, the essay maintains a thoughtful balance between optimism and caution regarding AI's impact in India, though it could expand on solutions to the highlighted issues for greater depth.",
#  'analysis_feedback': "The essay presents a comprehensive analysis of India's position in the rapidly evolving field of artificial intelligence. It effectively outlines both the potential benefits and the significant challenges posed by AI, demonstrating a balanced perspective that acknowledges existing strengths while also pinpointing key issues such as the digital divide, job displacement, and concerns over data privacy. The arguments are well-supported with relevant examples, such as applications in agriculture and healthcare, and references to government initiatives like the National AI Strategy add credibility to the analysis.\n\nHowever, the essay could benefit from a deeper exploration of specific case studies or statistics that illustrate the points made, especially concerning the real-world impact of AI integrations. This would enhance the critical thinking aspect by grounding the arguments in empirical data. Additionally, while the essay addresses the importance of a multi-stakeholder approach, it could elaborate on how such collaboration could be effectively implemented or provide examples of successful partnerships in this realm.\n\nOverall, the essay is well-structured and presents a persuasive argument for how India can navigate the challenges of AI. There is room for improvement in depth and specificity, but it effectively encourages a forward-looking perspective on AI's implications for India's future.",
#  'overall_feedback': "**Summarized Feedback**\n\nThe essay on India's position in the artificial intelligence (AI) landscape is commendable for its clear organization, logical flow, and quality of language, making it highly readable. It effectively introduces the topic and discusses both the potential benefits and challenges of AI, addressing key issues such as the digital divide, job displacement, and data privacy. The structure allows for a smooth transition between strengths, applications, and challenges, although some sentences could be more concise for improved clarity.\n\nWhile the analysis presents a balanced perspective and references government initiatives like the National AI Strategy for credibility, it would benefit from deeper exploration of specific case studies or statistics to ground the arguments in empirical evidence. Moreover, the essay could elaborate on multi-stakeholder collaboration strategies and provide examples of successful partnerships to enhance its depth.\n\nOverall, the essay presents a persuasive argument and maintains a thoughtful balance between optimism and caution regarding AI's impact in India. However, integrating more specific examples and encouraging a clearer presentation of solutions to the highlighted challenges would strengthen the analysis and provide a more actionable insight into the future of AI in India.",
#  'individual_scores': [8, 8, 8]}

# %%
essay2 = """India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

# %%
initial_state = {"essay": essay2}
final_state = workflow.invoke(initial_state)
final_state
# Out:
# {'essay': 'India and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language_feedback': 'The essay presents a clear perspective on the potential benefits and challenges of AI in India. It effectively highlights key areas such as agriculture, healthcare, and education where AI can make a substantial impact. However, there are numerous issues with language quality, including grammatical errors, sentence structure issues, and vocabulary choices that hinder the clarity and professionalism of the writing. For example, phrases like "new tech call Artificial Intel… something (AI)" and "go back" are informal and unclear. Furthermore, the use of non-standard English, such as "many good" and "big big data," detracts from the overall quality. Additionally, the essay lacks proper punctuation and organization, making it somewhat difficult to follow at times. Improving the grammar, refining vocabulary, and organizing ideas more logically would significantly elevate the language quality. Overall, the essay conveys a valuable message, but substantial improvements in language use are necessary.',
#  'clarity_feedback': 'The essay addresses the potential and challenges of AI in India, focusing on both positive aspects and concerns. However, the clarity and coherence are significantly undermined by several factors:\n\n1. **Sentence Structure**: Many sentences are incomplete or poorly constructed, making it difficult to follow the writer\'s ideas. Phrases such as "...new tech call Artificial Intel… something (AI)" are confusing and detract from the professionalism of the essay.\n\n2. **Grammar and Vocabulary**: The essay contains numerous grammatical errors, such as "India want become big" instead of "India wants to become big," and informal language, which limits the writing\'s overall quality and professionalism.\n\n3. **Logical Flow**: While the essay is organized into paragraphs, the transitions between ideas are weak. For instance, the introduction jumps directly from the potential of AI to problems without a smooth transition.\n\n4. **Development of Ideas**: Some points, such as the mention of the government program "AI for All," lack depth. More detail on how these programs work and their potential impact would enhance the essay\'s effectiveness. \n\n5. **Conclusion**: The conclusion is somewhat repetitive, reiterating points already made without providing a strong summary or call to action. \n\nOverall, while the essay touches on important themes regarding AI in India, improvements are necessary to enhance clarity, coherence, and professionalism. It could benefit from more structured and grammatically correct writing.\n\nAs such, I would assign this essay a score of 3 out of 10 for clarity and coherence.',
#  'analysis_feedback': "The essay presents a basic understanding of the potential of Artificial Intelligence (AI) in India, highlighting both opportunities and challenges. However, the analysis lacks depth and is plagued by numerous grammatical issues and unclear phrases that make it difficult to understand some of the arguments. The organization of thoughts is somewhat coherent but requires clearer transitions between ideas to build a stronger narrative. Key points like India's technological capabilities and the role of AI in various sectors are mentioned, yet the arguments could benefit from more examples or data to substantiate claims. Additionally, critical issues like privacy and job displacement are indeed important, but they are only superficially explored. A more nuanced discussion on these topics, with potential solutions, could improve the analysis significantly. Overall, while the essay highlights relevant points regarding AI's impact in India, the lack of critical depth and polish diminishes its effectiveness. A focus on clearer expression, stronger arguments, and a well-structured framework would enhance the essay's quality.",
#  'overall_feedback': '### Summarized Feedback\n\nThe essay presents a clear perspective on the potential benefits and challenges of AI in India, particularly in sectors like agriculture, healthcare, and education. However, the analysis is undermined by significant language quality issues, including grammatical errors, poor sentence structure, and informal vocabulary choices that obscure the message. Phrases like "new tech call Artificial Intel… something (AI)" and examples of non-standard English such as "many good" and "big big data" detract from the professionalism of the writing.\n\nWhile the essay displays a basic understanding of the opportunities and concerns surrounding AI, the depth of analysis is superficial, lacking essential examples or data to support claims. Issues like privacy and job displacement are raised, but the discussion lacks nuance and exploration of potential solutions. Additionally, the organization of thoughts suffers from weak transitions, leading to a disjointed narrative.\n\nImprovements are needed in sentence clarity, logical flow, and overall coherence. The development of ideas, particularly regarding government initiatives like "AI for All," requires further elaboration to enhance effectiveness. The conclusion reiterates points without providing a compelling summary or call to action.\n\nIn summary, while the essay addresses important themes related to AI in India, substantial improvements in language use, clarity, and analytical depth are necessary. A well-structured and grammatically correct approach would significantly elevate the quality of the writing. Overall, I would assign this essay a score of 3 out of 10 for clarity and coherence.',
#  'individual_scores': [4, 3, 4]}
